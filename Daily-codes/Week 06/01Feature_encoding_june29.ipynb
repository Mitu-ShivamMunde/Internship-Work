# %%
# Social_Networks_Ads.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
import os
print(os.listdir())
# Out:
# ['01Feature_encoding_june29.ipynb', '02Feaure_Scaling_Techniques_june30.ipynb', '03Classification_Dataset_july01.ipynb', '04Clustering_july02.ipynb', 'Social_Network_Ads.csv', 'test.exe']

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Lenovo\\Internship-Work\\Daily-codes\\Week 06'

# %%
import os
print(os.listdir())
# Out:
# ['01Feature_encoding_june29.ipynb', '02Feaure_Scaling_Techniques_june30.ipynb', '03Classification_Dataset_july01.ipynb', '04Clustering_july02.ipynb', 'Social_Network_Ads.csv', 'test.exe']
